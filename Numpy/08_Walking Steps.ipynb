# %%
import numpy as np

# %%
my_week = {
    'monday': 4315,
    'tuesday': 3009,
    'wednesday': 6318,
    'thursday': 2051,
    'friday': 4953,
    'saturday': 4059,
    'sunday': 3894
}

# %%
data = np.array(list(my_week.values()))
print('min: ', np.min(data))
print('max: ', np.max(data))
print('sum: ', np.sum(data))
print('average: ', np.average(data))
# Out:
# min:  2051
# max:  6318
# sum:  28599
# average:  4085.5714285714284
